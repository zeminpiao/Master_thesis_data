# %% [markdown]
# The deviation between spectrum on chip 3 and any other chips is higher than deviation between any other two chips

# %%
from calculate_tools import *
import numpy
#import mac

from PIL import Image
#import numpy
#numpy.set_printoptions(threshold=numpy.nan)
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from scipy import ndimage
import scipy
import scipy.io as sio
#from sklearn.metrics import mean_squared_error
import operator
import os
import dxchange
# %matplotlib notebook

global dataset_se
dataset_se = numpy.zeros([516, 516, 20])
global dataset_in
dataset_in = numpy.zeros([516, 516, 20])
global data_se_mf
global data_in_mf
#Create the Energy axis corresponding to the Threshold value
Energy_Value = [(0.0008706*i*i + 0.1*i+3.392)*1000 for i in range(47, 147, 10)]
print Energy_Value

data_se, data_in, data_se_mf, data_in_mf = data_initialization(dataset_se, dataset_in)
# Out:
# WARNING:dxchange.reader:netCDF4 module not found
# [10015.1554, 11920.579399999999, 14000.1234, 16253.787400000001, 18681.5714, 21283.4754, 24059.499400000004, 27009.643399999997, 30133.9074, 33432.2914]
# calculate_tools.py:47: RuntimeWarning: divide by zero encountered in log
#   data_se[:,:,ii] = numpy.subtract(numpy.log(data_subtr_ob[:,:,ii]), numpy.log(data_subtr_separate[:,:,ii]))
# calculate_tools.py:47: RuntimeWarning: invalid value encountered in log
#   data_se[:,:,ii] = numpy.subtract(numpy.log(data_subtr_ob[:,:,ii]), numpy.log(data_subtr_separate[:,:,ii]))
# calculate_tools.py:47: RuntimeWarning: invalid value encountered in subtract
#   data_se[:,:,ii] = numpy.subtract(numpy.log(data_subtr_ob[:,:,ii]), numpy.log(data_subtr_separate[:,:,ii]))
# calculate_tools.py:63: RuntimeWarning: divide by zero encountered in log
#   data_in[:,:,ii] = numpy.subtract(numpy.log(data_subtr_ob[:,:,ii]), numpy.log(data_subtr_interlacing[:,:,ii]))
# ...

# %%
coords = choose_region('separate')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
show_spectrum_region(coords[0], coords[1], 'separate', data_se, data_in, Energy_Value)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
spectrum_av1, spectrum_va1 = show_average_and_variance(coords[0], coords[1], 'separate', data_se, data_in, Energy_Value)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
coords = choose_region('separate')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
show_spectrum_region(coords[0], coords[1], 'separate', data_se, data_in, Energy_Value)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
spectrum_av2, spectrum_va2 = show_average_and_variance(coords[0], coords[1], 'separate', data_se, data_in, Energy_Value)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
coords = choose_region('separate')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
show_spectrum_region(coords[0], coords[1], 'separate', data_se, data_in, Energy_Value)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
spectrum_av3, spectrum_va3 = show_average_and_variance(coords[0], coords[1], 'separate', data_se, data_in, Energy_Value)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
coords = choose_region('separate')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
show_spectrum_region(coords[0], coords[1], 'separate', data_se, data_in, Energy_Value)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
spectrum_av4, spectrum_va4 = show_average_and_variance(coords[0], coords[1], 'separate', data_se, data_in, Energy_Value)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure(1314)
plt.plot(Energy_Value, spectrum_av1, 'r')
plt.plot(Energy_Value, spectrum_av2, 'y')
plt.plot(Energy_Value, spectrum_av3, 'b')
plt.plot(Energy_Value, spectrum_av4, 'g')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
variance_1_2 = numpy.var((spectrum_av1, spectrum_av2), axis=0)
variance_1_3 = numpy.var((spectrum_av1, spectrum_av3), axis=0)
variance_1_4 = numpy.var((spectrum_av1, spectrum_av4), axis=0)
variance_2_3 = numpy.var((spectrum_av2, spectrum_av3), axis=0)
variance_2_4 = numpy.var((spectrum_av2, spectrum_av4), axis=0)
variance_3_4 = numpy.var((spectrum_av3, spectrum_av4), axis=0)

plt.figure()
plt.plot(Energy_Value, variance_1_2, 'r')
plt.plot(Energy_Value, variance_1_3, 'g')
plt.plot(Energy_Value, variance_1_4, 'b')
plt.plot(Energy_Value, variance_2_3, 'y')
plt.plot(Energy_Value, variance_2_4)
plt.plot(Energy_Value, variance_3_4)
# Out:
# <img src="data:image/png;base64,..." width="640">
